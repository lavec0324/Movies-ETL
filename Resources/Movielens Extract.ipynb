# %%
import pandas as pd
import os

# %%
directory_path = os.getcwd()
print("My current directory is : " + directory_path)
folder_name = os.path.basename(directory_path)
print("My directory name is : " + folder_name)
# Out:
# My current directory is : C:\Users\lavec\OneDrive\Desktop\DataScience\Movies-ETL\Resources
# My directory name is : Resources

# %%
file_dir = 'C:/Users/lavec/OneDrive/Desktop/DataScience/Movies-ETL/Resources/'

# %%
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')

# %%
kaggle_metadata.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      110     1.0  1425941529
# 1       1      147     4.5  1425942435
# 2       1      858     5.0  1425941523
# 3       1     1221     5.0  1425941546
# 4       1     1246     5.0  1425941556

# %%
ratings.sample(n=5)  ## Sample of data frame
# Out:
#           userId  movieId  rating   timestamp
# 15907022  165475      162     4.0   939116352
# 1237951    12713     1552     3.0   944961752
# 8432133    86841     4545     1.5  1106861698
# 15468814  161003      232     5.0   841804163
# 24763417  257448    81834     5.0  1325892008

# %%
kaggle_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection   budget  \
# 22115  False                   NaN        0
# 2098   False                   NaN        0
# 21263  False                   NaN        0
# 12891  False                   NaN  4000000
# 27468  False                   NaN        0
#
#                                                   genres  \
# 22115                [{'id': 99, 'name': 'Documentary'}]
# 2098   [{'id': 12, 'name': 'Adventure'}, {'id': 80, '...
# 21263                      [{'id': 18, 'name': 'Drama'}]
# 12891  [{'id': 27, 'name': 'Horror'}, {'id': 18, 'nam...
# 27468                     [{'id': 35, 'name': 'Comedy'}]
#
#                                                 homepage      id    imdb_id  \
# 22115                                                NaN  162494  tt0263238
# 2098                                                 NaN   31995  tt0031505
# 21263  http://www.mylifetime.com/movies/the-client-li...   41180  tt1625340
# 12891               http://www.lettherightoneinmovie.com   13310  tt1139797
# 27468                                                NaN  177902  tt0026292
#
#       original_language                            original_title  \
# 22115                en  Crisis: Behind a Presidential Commitment
# 2098                 en                               Jamaica Inn
# 21263                en                           The Client List
# 12891                sv                    Låt den rätte komma in
# 27468                en                           Doubting Thomas
#
#                                                 overview  ... release_date  \
# 22115  During a two-day period before and after the U...  ...   1963-10-21
# 2098   In coastal Cornwall, England, during the early...  ...   1939-05-11
# 21263  After she and her husband lose their jobs, a f...  ...   2010-07-19
# 12891  Set in 1982 in the suburb of Blackeberg, Stock...  ...   2008-01-26
# 27468  A husband makes fun of his wife's theatrical a...  ...   1935-07-10
#
#           revenue runtime                          spoken_languages    status  \
# 22115         0.0    52.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2098          0.0   108.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 21263         0.0    88.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 12891  10785801.0   115.0  [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 27468         0.0    73.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 22115                                                NaN
# 2098                                                 NaN
# 21263          A mother will do anything for her family.
# 12891  Eli is 12 years old. She’s been 12 for over 20...
# 27468                                                NaN
#
#                                           title  video vote_average vote_count
# 22115  Crisis: Behind a Presidential Commitment  False          7.8        4.0
# 2098                                Jamaica Inn  False          5.6       43.0
# 21263                           The Client List  False          5.4       67.0
# 12891                      Let the Right One In  False          7.5      997.0
# 27468                           Doubting Thomas  False          0.0        0.0
#
# [5 rows x 24 columns]
